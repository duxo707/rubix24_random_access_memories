# %%
#model 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
pd.set_option('precision',3)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-4-61ab38d4a7ab> in <cell line: 3>()
#       1 pd.set_option('display.max_columns',None)
#       2 pd.set_option('display.max_rows',None)
# ----> 3 pd.set_option('precision',3)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     261
#     262     def __call__(self, *args, **kwds) -> T:
# --> 263         return self.__func__(*args, **kwds)
#     264
#     265     # error: Signature of "__doc__" incompatible with supertype "object"
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in _set_option(*args, **kwargs)
#     154
#     155     for k, v in zip(args[::2], args[1::2]):
# --> 156         key = _get_single_key(k, silent)
#     157
#     158         o = _get_registered_option(key)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_config/config.py in _get_single_key(pat, silent)
#     121         raise OptionError(f"No such keys(s): {repr(pat)}")
#     122     if len(keys) > 1:
# --> 123         raise OptionError("Pattern matched multiple keys")
#     124     key = keys[0]
#     125
#
# OptionError: Pattern matched multiple keys

# %%
generation_data = pd.read_csv('Plant_2_Generation_Data.csv')

# %%
weather_data = pd.read_csv('Plant_2_Weather_Sensor_Data.csv')

# %%
generation_data.sample(5).style.set_properties(
    **{
        'background-color': 'OliveDrab',
        'color': 'white',
        'border-color': 'darkblack'
    })
# Out:
# <style type="text/css">
# #T_09856_row0_col0, #T_09856_row0_col1, #T_09856_row0_col2, #T_09856_row0_col3, #T_09856_row0_col4, #T_09856_row0_col5, #T_09856_row0_col6, #T_09856_row1_col0, #T_09856_row1_col1, #T_09856_row1_col2, #T_09856_row1_col3, #T_09856_row1_col4, #T_09856_row1_col5, #T_09856_row1_col6, #T_09856_row2_col0, #T_09856_row2_col1, #T_09856_row2_col2, #T_09856_row2_col3, #T_09856_row2_col4, #T_09856_row2_col5, #T_09856_row2_col6, #T_09856_row3_col0, #T_09856_row3_col1, #T_09856_row3_col2, #T_09856_row3_col3, #T_09856_row3_col4, #T_09856_row3_col5, #T_09856_row3_col6, #T_09856_row4_col0, #T_09856_row4_col1, #T_09856_row4_col2, #T_09856_row4_col3, #T_09856_row4_col4, #T_09856_row4_col5, #T_09856_row4_col6 {
#   background-color: OliveDrab;
#   color: white;
#   border-color: darkblack;
# }
# </style>
# <table id="T_09856" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09856_level0_col0" class="col_heading level0 col0" >DATE_TIME</th>
#       <th id="T_09856_level0_col1" class="col_heading level0 col1" >PLANT_ID</th>
#       <th id="T_09856_level0_col2" class="col_heading level0 col2" >SOURCE_KEY</th>
#       <th id="T_09856_level0_col3" class="col_heading level0 col3" >DC_POWER</th>
#       <th id="T_09856_level0_col4" class="col_heading level0 col4" >AC_POWER</th>
#       <th id="T_09856_level0_col5" class="col_heading level0 col5" >DAILY_YIELD</th>
#       <th id="T_09856_level0_col6" class="col_heading level0 col6" >TOTAL_YIELD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09856_level0_row0" class="row_heading level0 row0" >55067</th>
#       <td id="T_09856_row0_col0" class="data row0 col0" >2020-06-12 00:15:00</td>
#       <td id="T_09856_row0_col1" class="data row0 col1" >4136001</td>
#       <td id="T_09856_row0_col2" class="data row0 col2" >vOuJvMaM2sgwLmb</td>
#       <td id="T_09856_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_09856_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_09856_row0_col5" class="data row0 col5" >3914.000000</td>
#       <td id="T_09856_row0_col6" class="data row0 col6" >2392945.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09856_level0_row1" class="row_heading level0 row1" >16513</th>
#       <td id="T_09856_row1_col0" class="data row1 col0" >2020-05-23 15:15:00</td>
#       <td id="T_09856_row1_col1" class="data row1 col1" >4136001</td>
#       <td id="T_09856_row1_col2" class="data row1 col2" >Et9kgGMDl729KT4</td>
#       <td id="T_09856_row1_col3" class="data row1 col3" >758.666667</td>
#       <td id="T_09856_row1_col4" class="data row1 col4" >742.760000</td>
#       <td id="T_09856_row1_col5" class="data row1 col5" >3483.866667</td>
#       <td id="T_09856_row1_col6" class="data row1 col6" >1742602.866667</td>
#     </tr>
#     <tr>
#       <th id="T_09856_level0_row2" class="row_heading level0 row2" >8457</th>
#       <td id="T_09856_row2_col0" class="data row2 col0" >2020-05-19 00:15:00</td>
#       <td id="T_09856_row2_col1" class="data row2 col1" >4136001</td>
#       <td id="T_09856_row2_col2" class="data row2 col2" >PeE6FRyGXUgsRhN</td>
#       <td id="T_09856_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_09856_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_09856_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_09856_row2_col6" class="data row2 col6" >1348376405.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09856_level0_row3" class="row_heading level0 row3" >20885</th>
#       <td id="T_09856_row3_col0" class="data row3 col0" >2020-05-26 04:00:00</td>
#       <td id="T_09856_row3_col1" class="data row3 col1" >4136001</td>
#       <td id="T_09856_row3_col2" class="data row3 col2" >81aHJ1q11NBPMrL</td>
#       <td id="T_09856_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_09856_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_09856_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_09856_row3_col6" class="data row3 col6" >1215345392.000000</td>
#     </tr>
#     <tr>
#       <th id="T_09856_level0_row4" class="row_heading level0 row4" >186</th>
#       <td id="T_09856_row4_col0" class="data row4 col0" >2020-05-15 02:00:00</td>
#       <td id="T_09856_row4_col1" class="data row4 col1" >4136001</td>
#       <td id="T_09856_row4_col2" class="data row4 col2" >Qf4GUc1pJu5T6c6</td>
#       <td id="T_09856_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_09856_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_09856_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_09856_row4_col6" class="data row4 col6" >838421377.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
weather_data.sample(5).style.set_properties(
    **{
        'background-color': 'pink',
        'color': 'Black',
        'border-color': 'darkblack'
    })
# Out:
# <style type="text/css">
# #T_8b7e8_row0_col0, #T_8b7e8_row0_col1, #T_8b7e8_row0_col2, #T_8b7e8_row0_col3, #T_8b7e8_row0_col4, #T_8b7e8_row0_col5, #T_8b7e8_row1_col0, #T_8b7e8_row1_col1, #T_8b7e8_row1_col2, #T_8b7e8_row1_col3, #T_8b7e8_row1_col4, #T_8b7e8_row1_col5, #T_8b7e8_row2_col0, #T_8b7e8_row2_col1, #T_8b7e8_row2_col2, #T_8b7e8_row2_col3, #T_8b7e8_row2_col4, #T_8b7e8_row2_col5, #T_8b7e8_row3_col0, #T_8b7e8_row3_col1, #T_8b7e8_row3_col2, #T_8b7e8_row3_col3, #T_8b7e8_row3_col4, #T_8b7e8_row3_col5, #T_8b7e8_row4_col0, #T_8b7e8_row4_col1, #T_8b7e8_row4_col2, #T_8b7e8_row4_col3, #T_8b7e8_row4_col4, #T_8b7e8_row4_col5 {
#   background-color: pink;
#   color: Black;
#   border-color: darkblack;
# }
# </style>
# <table id="T_8b7e8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b7e8_level0_col0" class="col_heading level0 col0" >DATE_TIME</th>
#       <th id="T_8b7e8_level0_col1" class="col_heading level0 col1" >PLANT_ID</th>
#       <th id="T_8b7e8_level0_col2" class="col_heading level0 col2" >SOURCE_KEY</th>
#       <th id="T_8b7e8_level0_col3" class="col_heading level0 col3" >AMBIENT_TEMPERATURE</th>
#       <th id="T_8b7e8_level0_col4" class="col_heading level0 col4" >MODULE_TEMPERATURE</th>
#       <th id="T_8b7e8_level0_col5" class="col_heading level0 col5" >IRRADIATION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b7e8_level0_row0" class="row_heading level0 row0" >573</th>
#       <td id="T_8b7e8_row0_col0" class="data row0 col0" >2020-05-20 23:45:00</td>
#       <td id="T_8b7e8_row0_col1" class="data row0 col1" >4136001</td>
#       <td id="T_8b7e8_row0_col2" class="data row0 col2" >iq8k7ZNt4Mwm3w0</td>
#       <td id="T_8b7e8_row0_col3" class="data row0 col3" >25.513830</td>
#       <td id="T_8b7e8_row0_col4" class="data row0 col4" >23.451961</td>
#       <td id="T_8b7e8_row0_col5" class="data row0 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8b7e8_level0_row1" class="row_heading level0 row1" >293</th>
#       <td id="T_8b7e8_row1_col0" class="data row1 col0" >2020-05-18 01:30:00</td>
#       <td id="T_8b7e8_row1_col1" class="data row1 col1" >4136001</td>
#       <td id="T_8b7e8_row1_col2" class="data row1 col2" >iq8k7ZNt4Mwm3w0</td>
#       <td id="T_8b7e8_row1_col3" class="data row1 col3" >25.534736</td>
#       <td id="T_8b7e8_row1_col4" class="data row1 col4" >24.604394</td>
#       <td id="T_8b7e8_row1_col5" class="data row1 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8b7e8_level0_row2" class="row_heading level0 row2" >1552</th>
#       <td id="T_8b7e8_row2_col0" class="data row2 col0" >2020-05-31 04:45:00</td>
#       <td id="T_8b7e8_row2_col1" class="data row2 col1" >4136001</td>
#       <td id="T_8b7e8_row2_col2" class="data row2 col2" >iq8k7ZNt4Mwm3w0</td>
#       <td id="T_8b7e8_row2_col3" class="data row2 col3" >25.622541</td>
#       <td id="T_8b7e8_row2_col4" class="data row2 col4" >23.556712</td>
#       <td id="T_8b7e8_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8b7e8_level0_row3" class="row_heading level0 row3" >1252</th>
#       <td id="T_8b7e8_row3_col0" class="data row3 col0" >2020-05-28 01:30:00</td>
#       <td id="T_8b7e8_row3_col1" class="data row3 col1" >4136001</td>
#       <td id="T_8b7e8_row3_col2" class="data row3 col2" >iq8k7ZNt4Mwm3w0</td>
#       <td id="T_8b7e8_row3_col3" class="data row3 col3" >26.332130</td>
#       <td id="T_8b7e8_row3_col4" class="data row3 col4" >25.194514</td>
#       <td id="T_8b7e8_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8b7e8_level0_row4" class="row_heading level0 row4" >3225</th>
#       <td id="T_8b7e8_row4_col0" class="data row4 col0" >2020-06-17 15:30:00</td>
#       <td id="T_8b7e8_row4_col1" class="data row4 col1" >4136001</td>
#       <td id="T_8b7e8_row4_col2" class="data row4 col2" >iq8k7ZNt4Mwm3w0</td>
#       <td id="T_8b7e8_row4_col3" class="data row4 col3" >27.700174</td>
#       <td id="T_8b7e8_row4_col4" class="data row4 col4" >32.386005</td>
#       <td id="T_8b7e8_row4_col5" class="data row4 col5" >0.237018</td>
#     </tr>
#   </tbody>
# </table>

# %%
generation_data['DATE_TIME'] = pd.to_datetime(generation_data['DATE_TIME'],format = '%Y-%m-%d %H:%M')
weather_data['DATE_TIME'] = pd.to_datetime(weather_data['DATE_TIME'],format = '%Y-%m-%d %H:%M:%S')

# %%
df_solar = pd.merge(generation_data.drop(columns = ['PLANT_ID']), weather_data.drop(columns = ['PLANT_ID', 'SOURCE_KEY']), on='DATE_TIME')
df_solar.sample(5).style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_a58f5_row0_col2, #T_a58f5_row0_col3, #T_a58f5_row0_col5, #T_a58f5_row0_col7, #T_a58f5_row0_col8, #T_a58f5_row1_col4, #T_a58f5_row1_col6 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_a58f5_row0_col4 {
#   background-color: #6b94ff;
#   color: #f1f1f1;
# }
# #T_a58f5_row0_col6 {
#   background-color: #49b6ff;
#   color: #000000;
# }
# #T_a58f5_row1_col2 {
#   background-color: #19e6ff;
#   color: #000000;
# }
# #T_a58f5_row1_col3, #T_a58f5_row1_col8 {
#   background-color: #18e7ff;
#   color: #000000;
# }
# #T_a58f5_row1_col5 {
#   background-color: #bc43ff;
#   color: #f1f1f1;
# }
# #T_a58f5_row1_col7 {
#   background-color: #d926ff;
#   color: #f1f1f1;
# }
# #T_a58f5_row2_col2, #T_a58f5_row2_col3 {
#   background-color: #4fb0ff;
#   color: #f1f1f1;
# }
# #T_a58f5_row2_col4 {
#   background-color: #02fdff;
#   color: #000000;
# }
# #T_a58f5_row2_col5, #T_a58f5_row3_col2, #T_a58f5_row3_col3, #T_a58f5_row3_col6, #T_a58f5_row3_col7, #T_a58f5_row3_col8, #T_a58f5_row4_col2, #T_a58f5_row4_col3, #T_a58f5_row4_col4, #T_a58f5_row4_col5, #T_a58f5_row4_col8 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_a58f5_row2_col6 {
#   background-color: #0bf4ff;
#   color: #000000;
# }
# #T_a58f5_row2_col7 {
#   background-color: #40bfff;
#   color: #000000;
# }
# #T_a58f5_row2_col8 {
#   background-color: #50afff;
#   color: #f1f1f1;
# }
# #T_a58f5_row3_col4 {
#   background-color: #4bb4ff;
#   color: #000000;
# }
# #T_a58f5_row3_col5 {
#   background-color: #0df2ff;
#   color: #000000;
# }
# #T_a58f5_row4_col6 {
#   background-color: #09f6ff;
#   color: #000000;
# }
# #T_a58f5_row4_col7 {
#   background-color: #0ef1ff;
#   color: #000000;
# }
# </style>
# <table id="T_a58f5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a58f5_level0_col0" class="col_heading level0 col0" >DATE_TIME</th>
#       <th id="T_a58f5_level0_col1" class="col_heading level0 col1" >SOURCE_KEY</th>
#       <th id="T_a58f5_level0_col2" class="col_heading level0 col2" >DC_POWER</th>
#       <th id="T_a58f5_level0_col3" class="col_heading level0 col3" >AC_POWER</th>
#       <th id="T_a58f5_level0_col4" class="col_heading level0 col4" >DAILY_YIELD</th>
#       <th id="T_a58f5_level0_col5" class="col_heading level0 col5" >TOTAL_YIELD</th>
#       <th id="T_a58f5_level0_col6" class="col_heading level0 col6" >AMBIENT_TEMPERATURE</th>
#       <th id="T_a58f5_level0_col7" class="col_heading level0 col7" >MODULE_TEMPERATURE</th>
#       <th id="T_a58f5_level0_col8" class="col_heading level0 col8" >IRRADIATION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a58f5_level0_row0" class="row_heading level0 row0" >56304</th>
#       <td id="T_a58f5_row0_col0" class="data row0 col0" >2020-06-12 14:30:00</td>
#       <td id="T_a58f5_row0_col1" class="data row0 col1" >9kRcWv60rDACzjR</td>
#       <td id="T_a58f5_row0_col2" class="data row0 col2" >489.326667</td>
#       <td id="T_a58f5_row0_col3" class="data row0 col3" >479.806667</td>
#       <td id="T_a58f5_row0_col4" class="data row0 col4" >3382.266667</td>
#       <td id="T_a58f5_row0_col5" class="data row0 col5" >2247888928.266666</td>
#       <td id="T_a58f5_row0_col6" class="data row0 col6" >26.867153</td>
#       <td id="T_a58f5_row0_col7" class="data row0 col7" >34.357570</td>
#       <td id="T_a58f5_row0_col8" class="data row0 col8" >0.325918</td>
#     </tr>
#     <tr>
#       <th id="T_a58f5_level0_row1" class="row_heading level0 row1" >3623</th>
#       <td id="T_a58f5_row1_col0" class="data row1 col0" >2020-05-16 17:15:00</td>
#       <td id="T_a58f5_row1_col1" class="data row1 col1" >oZ35aAeoifZaQzV</td>
#       <td id="T_a58f5_row1_col2" class="data row1 col2" >48.093333</td>
#       <td id="T_a58f5_row1_col3" class="data row1 col3" >46.533333</td>
#       <td id="T_a58f5_row1_col4" class="data row1 col4" >8050.733333</td>
#       <td id="T_a58f5_row1_col5" class="data row1 col5" >1659980197.733333</td>
#       <td id="T_a58f5_row1_col6" class="data row1 col6" >31.838677</td>
#       <td id="T_a58f5_row1_col7" class="data row1 col7" >32.712299</td>
#       <td id="T_a58f5_row1_col8" class="data row1 col8" >0.030800</td>
#     </tr>
#     <tr>
#       <th id="T_a58f5_level0_row2" class="row_heading level0 row2" >9061</th>
#       <td id="T_a58f5_row2_col0" class="data row2 col0" >2020-05-19 07:00:00</td>
#       <td id="T_a58f5_row2_col1" class="data row2 col1" >vOuJvMaM2sgwLmb</td>
#       <td id="T_a58f5_row2_col2" class="data row2 col2" >152.800000</td>
#       <td id="T_a58f5_row2_col3" class="data row2 col3" >149.406667</td>
#       <td id="T_a58f5_row2_col4" class="data row2 col4" >82.266667</td>
#       <td id="T_a58f5_row2_col5" class="data row2 col5" >2237117.266667</td>
#       <td id="T_a58f5_row2_col6" class="data row2 col6" >25.170779</td>
#       <td id="T_a58f5_row2_col7" class="data row2 col7" >26.249124</td>
#       <td id="T_a58f5_row2_col8" class="data row2 col8" >0.102572</td>
#     </tr>
#     <tr>
#       <th id="T_a58f5_level0_row3" class="row_heading level0 row3" >52822</th>
#       <td id="T_a58f5_row3_col0" class="data row3 col0" >2020-06-10 22:45:00</td>
#       <td id="T_a58f5_row3_col1" class="data row3 col1" >rrq4fwE8jgrTyWY</td>
#       <td id="T_a58f5_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_a58f5_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_a58f5_row3_col4" class="data row3 col4" >2369.000000</td>
#       <td id="T_a58f5_row3_col5" class="data row3 col5" >121097055.000000</td>
#       <td id="T_a58f5_row3_col6" class="data row3 col6" >24.871220</td>
#       <td id="T_a58f5_row3_col7" class="data row3 col7" >23.496776</td>
#       <td id="T_a58f5_row3_col8" class="data row3 col8" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a58f5_level0_row4" class="row_heading level0 row4" >443</th>
#       <td id="T_a58f5_row4_col0" class="data row4 col0" >2020-05-15 05:00:00</td>
#       <td id="T_a58f5_row4_col1" class="data row4 col1" >Et9kgGMDl729KT4</td>
#       <td id="T_a58f5_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_a58f5_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_a58f5_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_a58f5_row4_col5" class="data row4 col5" >1704250.000000</td>
#       <td id="T_a58f5_row4_col6" class="data row4 col6" >25.117599</td>
#       <td id="T_a58f5_row4_col7" class="data row4 col7" >24.104580</td>
#       <td id="T_a58f5_row4_col8" class="data row4 col8" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# adding separate time and date columns
df_solar["DATE"] = pd.to_datetime(df_solar["DATE_TIME"]).dt.date
df_solar["TIME"] = pd.to_datetime(df_solar["DATE_TIME"]).dt.time
df_solar['DAY'] = pd.to_datetime(df_solar['DATE_TIME']).dt.day
df_solar['MONTH'] = pd.to_datetime(df_solar['DATE_TIME']).dt.month
df_solar['WEEK'] = pd.to_datetime(df_solar['DATE_TIME']).dt.week


# add hours and minutes for ml models
df_solar['HOURS'] = pd.to_datetime(df_solar['TIME'],format='%H:%M:%S').dt.hour
df_solar['MINUTES'] = pd.to_datetime(df_solar['TIME'],format='%H:%M:%S').dt.minute
df_solar['TOTAL MINUTES PASS'] = df_solar['MINUTES'] + df_solar['HOURS']*60

# add date as string column
df_solar["DATE_STRING"] = df_solar["DATE"].astype(str) # add column with date as string
df_solar["HOURS"] = df_solar["HOURS"].astype(str)
df_solar["TIME"] = df_solar["TIME"].astype(str)

df_solar.head(2)
# Out:
#    DATE_TIME       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD   TOTAL_YIELD  \
# 0 2020-05-15  4UPUqMRk7TRMgml       0.0       0.0       9425.0  2.429011e+06
# 1 2020-05-15  81aHJ1q11NBPMrL       0.0       0.0          0.0  1.215279e+09
#
#    AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION        DATE      TIME  \
# 0            27.004764           25.060789          0.0  2020-05-15  00:00:00
# 1            27.004764           25.060789          0.0  2020-05-15  00:00:00
#
#    DAY  MONTH  WEEK HOURS  MINUTES  TOTAL MINUTES PASS DATE_STRING
# 0   15      5    20     0        0                   0  2020-05-15
# 1   15      5    20     0        0                   0  2020-05-15

# %%
df_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67698 entries, 0 to 67697
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            67698 non-null  datetime64[ns]
#  1   SOURCE_KEY           67698 non-null  object
#  2   DC_POWER             67698 non-null  float64
#  3   AC_POWER             67698 non-null  float64
#  4   DAILY_YIELD          67698 non-null  float64
#  5   TOTAL_YIELD          67698 non-null  float64
#  6   AMBIENT_TEMPERATURE  67698 non-null  float64
#  7   MODULE_TEMPERATURE   67698 non-null  float64
#  8   IRRADIATION          67698 non-null  float64
#  9   DATE                 67698 non-null  object
#  10  TIME                 67698 non-null  object
#  11  DAY                  67698 non-null  int64
#  12  MONTH                67698 non-null  int64
#  13  WEEK                 67698 non-null  int64
#  14  HOURS                67698 non-null  object
#  15  MINUTES              67698 non-null  int64
#  16  TOTAL MINUTES PASS   67698 non-null  int64
#  17  DATE_STRING          67698 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(5), object(5)
# memory usage: 9.8+ MB

# %%
df_solar.isnull().sum()
# Out:
# DATE_TIME              0
# SOURCE_KEY             0
# DC_POWER               0
# AC_POWER               0
# DAILY_YIELD            0
# TOTAL_YIELD            0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# DATE                   0
# TIME                   0
# DAY                    0
# MONTH                  0
# WEEK                   0
# HOURS                  0
# MINUTES                0
# TOTAL MINUTES PASS     0
# DATE_STRING            0
# dtype: int64

# %%
df_solar.describe().style.background_gradient(cmap='rainbow')
# Out:
# <style type="text/css">
# #T_65bc8_row0_col0, #T_65bc8_row0_col1, #T_65bc8_row0_col2, #T_65bc8_row0_col4, #T_65bc8_row0_col5, #T_65bc8_row0_col6, #T_65bc8_row0_col7, #T_65bc8_row0_col8, #T_65bc8_row0_col9, #T_65bc8_row0_col10, #T_65bc8_row0_col11, #T_65bc8_row7_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_65bc8_row0_col3, #T_65bc8_row1_col0, #T_65bc8_row1_col1, #T_65bc8_row1_col4, #T_65bc8_row1_col5, #T_65bc8_row1_col6, #T_65bc8_row1_col7, #T_65bc8_row1_col8, #T_65bc8_row1_col9, #T_65bc8_row1_col10, #T_65bc8_row2_col4, #T_65bc8_row2_col5, #T_65bc8_row2_col6, #T_65bc8_row2_col7, #T_65bc8_row2_col8, #T_65bc8_row2_col9, #T_65bc8_row2_col10, #T_65bc8_row3_col0, #T_65bc8_row3_col1, #T_65bc8_row3_col2, #T_65bc8_row3_col3, #T_65bc8_row3_col4, #T_65bc8_row3_col5, #T_65bc8_row3_col6, #T_65bc8_row3_col7, #T_65bc8_row3_col8, #T_65bc8_row3_col9, #T_65bc8_row3_col10, #T_65bc8_row3_col11, #T_65bc8_row4_col0, #T_65bc8_row4_col1, #T_65bc8_row4_col4, #T_65bc8_row4_col5, #T_65bc8_row4_col6, #T_65bc8_row4_col7, #T_65bc8_row4_col8, #T_65bc8_row4_col9, #T_65bc8_row4_col10, #T_65bc8_row5_col0, #T_65bc8_row5_col1, #T_65bc8_row5_col4, #T_65bc8_row5_col5, #T_65bc8_row5_col6, #T_65bc8_row5_col7, #T_65bc8_row5_col8, #T_65bc8_row5_col9, #T_65bc8_row5_col10, #T_65bc8_row6_col4, #T_65bc8_row6_col5, #T_65bc8_row6_col6, #T_65bc8_row6_col7, #T_65bc8_row6_col8, #T_65bc8_row6_col9, #T_65bc8_row6_col10, #T_65bc8_row7_col4, #T_65bc8_row7_col5, #T_65bc8_row7_col6, #T_65bc8_row7_col7, #T_65bc8_row7_col8, #T_65bc8_row7_col9, #T_65bc8_row7_col10 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_65bc8_row1_col2 {
#   background-color: #6826fe;
#   color: #f1f1f1;
# }
# #T_65bc8_row1_col3 {
#   background-color: #17cbe4;
#   color: #000000;
# }
# #T_65bc8_row1_col11, #T_65bc8_row4_col3, #T_65bc8_row5_col11 {
#   background-color: #7c06ff;
#   color: #f1f1f1;
# }
# #T_65bc8_row2_col0, #T_65bc8_row2_col1, #T_65bc8_row2_col11, #T_65bc8_row4_col2, #T_65bc8_row4_col11, #T_65bc8_row6_col0, #T_65bc8_row6_col1 {
#   background-color: #7e03ff;
#   color: #f1f1f1;
# }
# #T_65bc8_row2_col2, #T_65bc8_row5_col2 {
#   background-color: #6a22fe;
#   color: #f1f1f1;
# }
# #T_65bc8_row2_col3 {
#   background-color: #27dade;
#   color: #000000;
# }
# #T_65bc8_row5_col3 {
#   background-color: #4062fa;
#   color: #f1f1f1;
# }
# #T_65bc8_row6_col2 {
#   background-color: #583efd;
#   color: #f1f1f1;
# }
# #T_65bc8_row6_col3 {
#   background-color: #b2f396;
#   color: #000000;
# }
# #T_65bc8_row6_col11 {
#   background-color: #780dff;
#   color: #f1f1f1;
# }
# #T_65bc8_row7_col0, #T_65bc8_row7_col1, #T_65bc8_row7_col11 {
#   background-color: #7610ff;
#   color: #f1f1f1;
# }
# #T_65bc8_row7_col2 {
#   background-color: #3670f8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_65bc8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65bc8_level0_col0" class="col_heading level0 col0" >DC_POWER</th>
#       <th id="T_65bc8_level0_col1" class="col_heading level0 col1" >AC_POWER</th>
#       <th id="T_65bc8_level0_col2" class="col_heading level0 col2" >DAILY_YIELD</th>
#       <th id="T_65bc8_level0_col3" class="col_heading level0 col3" >TOTAL_YIELD</th>
#       <th id="T_65bc8_level0_col4" class="col_heading level0 col4" >AMBIENT_TEMPERATURE</th>
#       <th id="T_65bc8_level0_col5" class="col_heading level0 col5" >MODULE_TEMPERATURE</th>
#       <th id="T_65bc8_level0_col6" class="col_heading level0 col6" >IRRADIATION</th>
#       <th id="T_65bc8_level0_col7" class="col_heading level0 col7" >DAY</th>
#       <th id="T_65bc8_level0_col8" class="col_heading level0 col8" >MONTH</th>
#       <th id="T_65bc8_level0_col9" class="col_heading level0 col9" >WEEK</th>
#       <th id="T_65bc8_level0_col10" class="col_heading level0 col10" >MINUTES</th>
#       <th id="T_65bc8_level0_col11" class="col_heading level0 col11" >TOTAL MINUTES PASS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65bc8_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_65bc8_row0_col0" class="data row0 col0" >67698.000000</td>
#       <td id="T_65bc8_row0_col1" class="data row0 col1" >67698.000000</td>
#       <td id="T_65bc8_row0_col2" class="data row0 col2" >67698.000000</td>
#       <td id="T_65bc8_row0_col3" class="data row0 col3" >67698.000000</td>
#       <td id="T_65bc8_row0_col4" class="data row0 col4" >67698.000000</td>
#       <td id="T_65bc8_row0_col5" class="data row0 col5" >67698.000000</td>
#       <td id="T_65bc8_row0_col6" class="data row0 col6" >67698.000000</td>
#       <td id="T_65bc8_row0_col7" class="data row0 col7" >67698.000000</td>
#       <td id="T_65bc8_row0_col8" class="data row0 col8" >67698.000000</td>
#       <td id="T_65bc8_row0_col9" class="data row0 col9" >67698.000000</td>
#       <td id="T_65bc8_row0_col10" class="data row0 col10" >67698.000000</td>
#       <td id="T_65bc8_row0_col11" class="data row0 col11" >67698.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65bc8_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_65bc8_row1_col0" class="data row1 col0" >246.701961</td>
#       <td id="T_65bc8_row1_col1" class="data row1 col1" >241.277825</td>
#       <td id="T_65bc8_row1_col2" class="data row1 col2" >3294.890295</td>
#       <td id="T_65bc8_row1_col3" class="data row1 col3" >658944788.423766</td>
#       <td id="T_65bc8_row1_col4" class="data row1 col4" >27.986756</td>
#       <td id="T_65bc8_row1_col5" class="data row1 col5" >32.607233</td>
#       <td id="T_65bc8_row1_col6" class="data row1 col6" >0.229204</td>
#       <td id="T_65bc8_row1_col7" class="data row1 col7" >15.530680</td>
#       <td id="T_65bc8_row1_col8" class="data row1 col8" >5.529705</td>
#       <td id="T_65bc8_row1_col9" class="data row1 col9" >22.563296</td>
#       <td id="T_65bc8_row1_col10" class="data row1 col10" >22.517061</td>
#       <td id="T_65bc8_row1_col11" class="data row1 col11" >714.329522</td>
#     </tr>
#     <tr>
#       <th id="T_65bc8_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_65bc8_row2_col0" class="data row2 col0" >370.569597</td>
#       <td id="T_65bc8_row2_col1" class="data row2 col1" >362.112118</td>
#       <td id="T_65bc8_row2_col2" class="data row2 col2" >2919.448386</td>
#       <td id="T_65bc8_row2_col3" class="data row2 col3" >729667771.073241</td>
#       <td id="T_65bc8_row2_col4" class="data row2 col4" >4.021294</td>
#       <td id="T_65bc8_row2_col5" class="data row2 col5" >11.226446</td>
#       <td id="T_65bc8_row2_col6" class="data row2 col6" >0.309365</td>
#       <td id="T_65bc8_row2_col7" class="data row2 col7" >8.527546</td>
#       <td id="T_65bc8_row2_col8" class="data row2 col8" >0.499120</td>
#       <td id="T_65bc8_row2_col9" class="data row2 col9" >1.474730</td>
#       <td id="T_65bc8_row2_col10" class="data row2 col10" >16.764084</td>
#       <td id="T_65bc8_row2_col11" class="data row2 col11" >415.672274</td>
#     </tr>
#     <tr>
#       <th id="T_65bc8_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_65bc8_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_65bc8_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_65bc8_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_65bc8_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_65bc8_row3_col4" class="data row3 col4" >20.942385</td>
#       <td id="T_65bc8_row3_col5" class="data row3 col5" >20.265123</td>
#       <td id="T_65bc8_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_65bc8_row3_col7" class="data row3 col7" >1.000000</td>
#       <td id="T_65bc8_row3_col8" class="data row3 col8" >5.000000</td>
#       <td id="T_65bc8_row3_col9" class="data row3 col9" >20.000000</td>
#       <td id="T_65bc8_row3_col10" class="data row3 col10" >0.000000</td>
#       <td id="T_65bc8_row3_col11" class="data row3 col11" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_65bc8_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_65bc8_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_65bc8_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_65bc8_row4_col2" class="data row4 co

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df_solar['SOURCE_KEY_NUMBER'] = encoder.fit_transform(df_solar['SOURCE_KEY'])
df_solar.head()
# Out:
#    DATE_TIME       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD   TOTAL_YIELD  \
# 0 2020-05-15  4UPUqMRk7TRMgml       0.0       0.0  9425.000000  2.429011e+06
# 1 2020-05-15  81aHJ1q11NBPMrL       0.0       0.0     0.000000  1.215279e+09
# 2 2020-05-15  9kRcWv60rDACzjR       0.0       0.0  3075.333333  2.247720e+09
# 3 2020-05-15  Et9kgGMDl729KT4       0.0       0.0   269.933333  1.704250e+06
# 4 2020-05-15  IQ2d7wF4YD8zU1Q       0.0       0.0  3177.000000  1.994153e+07
#
#    AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION        DATE      TIME  \
# 0            27.004764           25.060789          0.0  2020-05-15  00:00:00
# 1            27.004764           25.060789          0.0  2020-05-15  00:00:00
# 2            27.004764           25.060789          0.0  2020-05-15  00:00:00
# 3            27.004764           25.060789          0.0  2020-05-15  00:00:00
# 4            27.004764           25.060789          0.0  2020-05-15  00:00:00
#
#    DAY  MONTH  WEEK HOURS  MINUTES  TOTAL MINUTES PASS DATE_STRING  \
# 0   15      5    20     0        0                   0  2020-05-15
# 1   15      5    20     0        0                   0  2020-05-15
# 2   15      5    20     0        0                   0  2020-05-15
# 3   15      5    20     0        0                   0  2020-05-15
# 4   15      5    20     0        0                   0  2020-05-15
#
#    SOURCE_KEY_NUMBER
# 0                  0
# 1                  1
# 2                  2
# 3                  3
# 4                  4
